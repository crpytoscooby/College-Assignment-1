# %% [markdown]
# ## Assignment 2
# 1. Assess the performance of regression models using MSE, MAE and R-Square metrics
# 1. Visualize simple regression model.

# %% [markdown]
# ### Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Importing dataset

# %%
data = pd.read_csv('.//Dataset//Regression_Data_set_Batch1.csv')

# %% [markdown]
# ### Checking for missing values

# %%
data.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %% [markdown]
# ### Handling the categorical values

# %%
# converting yes no values to 1 and 0 respectively
data["mainroad"] = data["mainroad"].map({"yes": 1, "no": 0})

data["guestroom"] = data["guestroom"].map({"yes": 1, "no": 0})

data["basement"] = data["basement"].map({"yes": 1, "no": 0})

data["hotwaterheating"] = data["hotwaterheating"].map({"yes": 1, "no": 0})

data["airconditioning"] = data["airconditioning"].map({"yes": 1, "no": 0})

data["prefarea"] = data["prefarea"].map({"yes": 1, "no": 0})

# %%
# there is also a method to convert categorical values into numbers

furnished_data = pd.get_dummies(data["furnishingstatus"], prefix = "furnish_stats", drop_first = True)
# if I dont mention drop_first = True, then it will create 3 columns viz. furnished, semi-furnished and unfurnished


#                 semi-furnished      unfurnished
# furnished           0                   0
# semi-furnished      1                   0
# unfurnished         0                   1

# %%
data.drop("furnishingstatus", axis = 1, inplace = True)
data = pd.concat([data, furnished_data], axis = 1)

# %%
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    furnish_stats_semi-furnished  furnish_stats_unfurnished
# 0                             0                          0
# ...

# %% [markdown]
# ### Spliting independent and dependent variable

# %%
feature_names = ["area", "bedrooms", "bathrooms", "stories", "mainroad", "guestroom", "basement", "hotwaterheating", "airconditioning", "parking", "prefarea", "furnish_stats_semi-furnished", "furnish_stats_unfurnished"]
target = ["price"]
X = data[feature_names] # regressor or independent variables
y = data[target]  # target or dependent variable

# %% [markdown]
# ### Spliting the dataset

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %% [markdown]
# ### Correlational matrix

# %%
# correlational matrix
correlation = data.corr()
correlation
# Out:
#                                  price      area  bedrooms  bathrooms  \
# price                         1.000000  0.535997  0.366494   0.517545
# area                          0.535997  1.000000  0.151858   0.193820
# bedrooms                      0.366494  0.151858  1.000000   0.373930
# bathrooms                     0.517545  0.193820  0.373930   1.000000
# stories                       0.420712  0.083996  0.408564   0.326165
# mainroad                      0.296898  0.288874 -0.012033   0.042398
# guestroom                     0.255517  0.140297  0.080549   0.126469
# basement                      0.187057  0.047417  0.097312   0.102106
# hotwaterheating               0.093073 -0.009229  0.046049   0.067159
# airconditioning               0.452954  0.222393  0.160603   0.186915
# parking                       0.384394  0.352980  0.139270   0.177496
# prefarea                      0.329777  0.234779  0.079023   0.063472
# ...

# %%
# checking correlation using heatmap
sns.heatmap(data.corr(), vmax = 0.8, square = True, annot = True, fmt = ".1f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Ordinary Least Squares (OLS)

# %%
import statsmodels.api as sm

model = sm.OLS(y_train, X_train).fit()
print(model.summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared (uncentered):                   0.955
# Model:                            OLS   Adj. R-squared (uncentered):              0.953
# Method:                 Least Squares   F-statistic:                              693.3
# Date:                Sat, 25 Sep 2021   Prob (F-statistic):                   3.16e-257
# Time:                        10:05:59   Log-Likelihood:                         -6255.3
# No. Observations:                 408   AIC:                                  1.253e+04
# Df Residuals:                     396   BIC:                                  1.258e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# ...
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# ...
