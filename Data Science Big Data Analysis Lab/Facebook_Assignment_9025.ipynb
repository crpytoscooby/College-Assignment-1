# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = "/content/drive/MyDrive/TE Sem 2/dataset_Facebook.csv"
data = pd.read_csv(path,sep = ";")

# %%
data
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
# Values greater than 5 in the Post Hour column
data_posthour = data[data['Post Hour'] > 5]
data_posthour
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1              139441  Status         2          12             3         10
# 3              139441   Photo         2          12             2         10
# 5              139441  Status         2          12             1          9
# 7              139441   Photo         3          12             7          9
# 9              139441   Photo         3          12             6         10
# ..                ...     ...       ...         ...           ...        ...
# 490             85979   Photo         3           1             6         11
# 492             85979    Link         1           1             5         11
# 494             85093   Photo         3           1             7         10
# 496             81370   Photo         2           1             5          8
# 498             81370   Photo         3           1             4         11
#
# ...

# %%
# Only entries with Type as Photo
data_photo = data[data['Type']=='Photo']
data_photo
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441  Photo         2          12             4          3
# 2              139441  Photo         3          12             3          3
# 3              139441  Photo         2          12             2         10
# 4              139441  Photo         2          12             2          3
# 6              139441  Photo         3          12             1          3
# ..                ...    ...       ...         ...           ...        ...
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
# ...

# %%
# entries from rows 30 to 40 and columns 12 to 15

subset=data.iloc[30:40,12:15]
subset
# Out:
#     Lifetime Post Impressions by people who have liked your Page  \
# 30                                               5860
# 31                                               1585
# 32                                               4480
# 33                                               3039
# 34                                               5782
# 35                                               5183
# 36                                               3052
# 37                                               5187
# 38                                              23135
# 39                                               4986
#
#     Lifetime Post reach by people who like your Page  \
# 30                                              2930
# 31                                               858
# 32                                              2422
# 33                                              1676
# 34                                              2938
# ...

# %%
# sort_values is used for sorting all the values in ascending or descending values
# by default it is ascending order

df = data
df.sort_values("Lifetime Post Total Impressions")
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 422            102112  Photo         1           3             1         19
# 432            100732  Photo         1           3             6         17
# 426            100732  Photo         1           3             7         18
# 120            136393  Photo         1          10             7          9
# 123            136393  Photo         1          10             7          7
# ..                ...    ...       ...         ...           ...        ...
# 464             92079  Photo         1           2             6         13
# 437            100732  Photo         1           3             6         10
# 463             92186  Photo         3           2             7          2
# 460             92507  Photo         3           2             1         13
# 415            104070  Photo         1           3             4          7
#
# ...

# %%
# sort_values in descending order

df.sort_values(by="Lifetime Post Total Reach", ascending=False)
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 244            130791  Photo         2           7             3          5
# 464             92079  Photo         1           2             6         13
# 463             92186  Photo         3           2             7          2
# 277            126424  Video         1           6             2         13
# 380            111620  Photo         1           4             7         14
# ..                ...    ...       ...         ...           ...        ...
# 123            136393  Photo         1          10             7          7
# 120            136393  Photo         1          10             7          9
# 432            100732  Photo         1           3             6         17
# 426            100732  Photo         1           3             7         18
# 422            102112  Photo         1           3             1         19
#
# ...

# %%
# Entries with only post weekday = 3 are separated and the shape is printed

my_dataframe1 = data[['Post Month', 'Post Weekday', 'Post Hour']]
data_postweek = data[data['Post Weekday']==3]
my_dataframe1.shape
# Out:
# (500, 3)

# %%
data_postweek.shape
# Out:
# (64, 19)

# %%
# merge the two datasets

merged = pd.merge(my_dataframe1, data_postweek)
merged
# Out:
#      Post Month  Post Weekday  Post Hour  Page total likes    Type  Category  \
# 0            12             3         10            139441  Status         2
# 1            12             3         10            138414  Status         2
# 2            12             3         10            138895   Photo         2
# 3            12             3         10            139441  Status         2
# 4            12             3         10            138414  Status         2
# ..          ...           ...        ...               ...     ...       ...
# 107           2             3          9             92935   Photo         1
# 108           2             3          6             92828   Photo         1
# 109           2             3          3             91330   Photo         3
# 110           1             3         10             86491   Photo         3
# 111           1             3          3             86491   Photo         2
#
# ...

# %%
# to transpose index and columns of the dataframe
data.T
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
# create a dataframe with only following columns
dataframe = data[['like', 'share', 'Category', 'Type']]

# %%
# pivot table with category and index as features
reshape_data = dataframe.pivot_table(index=["Category", 'like'])
reshape_data
# Out:
#                       share
# Category like
# 1        0.0       0.000000
#          1.0       2.000000
#          2.0       0.000000
#          3.0       0.666667
#          4.0       1.000000
# ...                     ...
# 3        1155.0  102.000000
#          1372.0   47.000000
#          1546.0  181.000000
#          1639.0  122.000000
#          1998.0  128.000000
#
# [368 rows x 1 columns]

# %%
reshape_data.reset_index
# Out:
# <bound method DataFrame.reset_index of                       share
# Category like
# 1        0.0       0.000000
#          1.0       2.000000
#          2.0       0.000000
#          3.0       0.666667
#          4.0       1.000000
# ...                     ...
# 3        1155.0  102.000000
#          1372.0   47.000000
#          1546.0  181.000000
#          1639.0  122.000000
#          1998.0  128.000000
#
# [368 rows x 1 columns]>

# %%
# value_vars are variables, basically used as unpivot

pd.melt(data, value_vars=['like','share'])
# Out:
#     variable   value
# 0       like    79.0
# 1       like   130.0
# 2       like    66.0
# 3       like  1572.0
# 4       like   325.0
# ..       ...     ...
# 995    share    26.0
# 996    share    22.0
# 997    share    18.0
# 998    share    38.0
# 999    share    28.0
#
# [1000 rows x 2 columns]

# %%
# to reshape data with the specified column name or index
# index as id_vars and columns as variable column

data.pivot(columns="Category", values="like")
# Out:
# Category     1       2     3
# 0          NaN    79.0   NaN
# 1          NaN   130.0   NaN
# 2          NaN     NaN  66.0
# 3          NaN  1572.0   NaN
# 4          NaN   325.0   NaN
# ..         ...     ...   ...
# 495        NaN     NaN  53.0
# 496        NaN    53.0   NaN
# 497       93.0     NaN   NaN
# 498        NaN     NaN  91.0
# 499        NaN    91.0   NaN
#
# [500 rows x 3 columns]
